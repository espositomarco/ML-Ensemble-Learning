# %%
from __future__ import print_function
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.metrics import classification_report, accuracy_score
from sklearn.svm import SVC
import MajorityClassifier as MCL
import numpy as np
import pandas as pd
import generate_results as gr
from python.dataset_info import datasets
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import warnings
warnings.filterwarnings("ignore")
header = "model,dataset,scoring,P1_best,P2_best,cv_acc,val_acc"
output = "results/params_tuning.csv"
with open(output, "a") as f:
    f.write(header+'\n')

parameters = {'svm': {'kernel' : ['linear', 'poly', 'rbf', 'sigmoid'], 'C': [1,10,100,1000]},
          'rf': {'n_estimators': [10, 30, 50, 100], 'max_depth': [None,1,3]},
          'knn': {'n_neighbors': [1,3,5,8,10,30], 'weights': ['uniform', 'distance']},
          'mnb': {},
          'mlp': {'activation': ['identity', 'relu', 'logistic'], 'alpha': [0.001, 1.0000000000000001e-05, 9.9999999999999995e-07]}}

# Split the dataset 70/30
for dataset in list(datasets.keys()):
    X, y = gr.read_dataset(datasets[dataset])
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=0)
    y_train = np.ravel(y_train)
    y_test = np.ravel(y_test)
    scores = ['accuracy']#,'precision_macro', 'recall_macro']
    for label, model in {'svm': SVC(),'knn':KNeighborsClassifier(),'rf': RandomForestClassifier(), 'mlp': MLPClassifier()}.items():
        for score in scores:
            print("# Tuning hyper-parameters for %s, model %s" % (score, model.__class__.__name__))
            print()
            #clf = GridSearchCV(model, parameters[label], cv=5,scoring=('%s' % score))
            clf = GridSearchCV(model, parameters[label], cv=5,scoring=('%s' % score))
            
            clf.fit(X_train, y_train)

            print("Best parameters set found on development set:")
            print()
            print(clf.best_params_)
            print()
            print("Grid scores on development set:")
            print()
            means = clf.cv_results_['mean_test_score']
            stds = clf.cv_results_['std_test_score']
            for mean, std, params in zip(means, stds, clf.cv_results_['params']):
                print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
            print()

            print("Detailed classification report:")
            print()
            print("The model is trained on the full development set.")
            print("The scores are computed on the full evaluation set.")
            print()
            y_true, y_pred = y_test, clf.predict(X_test)
            print(classification_report(y_true, y_pred))
            print()
            res_str = "%s,%s,%s,%s,%s,%.2f,%.2f" % (model.__class__.__name__,
                                                        dataset,
                                                        score,
                                                        list(clf.best_params_.values())[0],
                                                        list(clf.best_params_.values())[1],
                                                        max(means),
                                                        accuracy_score(y_true, y_pred))
            print(res_str)
            with open(output, "a") as f:
                f.write(res_str + '\n')
# Out:
# # Tuning hyper-parameters for accuracy, model SVC
#
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.742 (+/-0.027) for {'C': 1, 'kernel': 'linear'}
# 0.542 (+/-0.020) for {'C': 1, 'kernel': 'poly'}
# 0.542 (+/-0.020) for {'C': 1, 'kernel': 'rbf'}
# 0.542 (+/-0.020) for {'C': 1, 'kernel': 'sigmoid'}
# 0.802 (+/-0.064) for {'C': 10, 'kernel': 'linear'}
# 0.542 (+/-0.020) for {'C': 10, 'kernel': 'poly'}
# 0.689 (+/-0.042) for {'C': 10, 'kernel': 'rbf'}
# 0.610 (+/-0.062) for {'C': 10, 'kernel': 'sigmoid'}
# 0.859 (+/-0.084) for {'C': 100, 'kernel': 'linear'}
# 0.725 (+/-0.047) for {'C': 100, 'kernel': 'poly'}
# 0.778 (+/-0.054) for {'C': 100, 'kernel': 'rbf'}
# 0.769 (+/-0.063) for {'C': 100, 'kernel': 'sigmoid'}
# 0.855 (+/-0.075) for {'C': 1000, 'kernel': 'linear'}
# 0.709 (+/-0.058) for {'C': 1000, 'kernel': 'poly'}
# 0.744 (+/-0.086) for {'C': 1000, 'kernel': 'rbf'}
# 0.758 (+/-0.092) for {'C': 1000, 'kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.50      0.50      0.50         4
#           1       0.91      1.00      0.95        31
#           2       1.00      1.00      1.00         4
#           3       1.00      1.00      1.00       109
#           4       0.89      0.81      0.85        21
#           5       1.00      0.96      0.98        26
#
# avg / total       0.96      0.96      0.96       195
#
#
# SVC,student,accuracy,100,linear,0.86,0.96
# # Tuning hyper-parameters for accuracy, model KNeighborsClassifier
#
# Best parameters set found on development set:
#
# {'n_neighbors': 10, 'weights': 'uniform'}
#
# Grid scores on development set:
#
# 0.452 (+/-0.079) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.452 (+/-0.079) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.449 (+/-0.092) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.458 (+/-0.096) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.498 (+/-0.041) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.491 (+/-0.053) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.518 (+/-0.073) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.515 (+/-0.061) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.542 (+/-0.037) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.535 (+/-0.058) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.540 (+/-0.025) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.540 (+/-0.014) for {'n_neighbors': 30, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         4
#           1       0.26      0.23      0.24        31
#           2       0.00      0.00      0.00         4
#           3       0.62      0.89      0.73       109
#           4       0.50      0.10      0.16        21
#           5       0.75      0.23      0.35        26
#
# avg / total       0.54      0.57      0.51       195
#
#
# KNeighborsClassifier,student,accuracy,10,uniform,0.54,0.57
# # Tuning hyper-parameters for accuracy, model RandomForestClassifier
#
# Best parameters set found on development set:
#
# {'max_depth': None, 'n_estimators': 30}
#
# Grid scores on development set:
#
# 0.910 (+/-0.066) for {'max_depth': None, 'n_estimators': 10}
# 0.963 (+/-0.025) for {'max_depth': None, 'n_estimators': 30}
# 0.960 (+/-0.040) for {'max_depth': None, 'n_estimators': 50}
# 0.954 (+/-0.017) for {'max_depth': None, 'n_estimators': 100}
# 0.595 (+/-0.082) for {'max_depth': 1, 'n_estimators': 10}
# 0.586 (+/-0.113) for {'max_depth': 1, 'n_estimators': 30}
# 0.559 (+/-0.088) for {'max_depth': 1, 'n_estimators': 50}
# 0.551 (+/-0.019) for {'max_depth': 1, 'n_estimators': 100}
# 0.784 (+/-0.086) for {'max_depth': 3, 'n_estimators': 10}
# 0.747 (+/-0.080) for {'max_depth': 3, 'n_estimators': 30}
# 0.767 (+/-0.052) for {'max_depth': 3, 'n_estimators': 50}
# 0.780 (+/-0.053) for {'max_depth': 3, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      0.75      0.86         4
#           1       1.00      0.97      0.98        31
#           2       1.00      0.75      0.86         4
#           3       0.97      1.00      0.99       109
#           4       0.95      1.00      0.98        21
#           5       1.00      0.96      0.98        26
#
# avg / total       0.98      0.98      0.98       195
#
#
# RandomForestClassifier,student,accuracy,None,30,0.96,0.98
# # Tuning hyper-parameters for accuracy, model MLPClassifier
#
# Best parameters set found on development set:
#
# {'activation': 'relu', 'alpha': 0.001}
#
# Grid scores on development set:
#
# 0.615 (+/-0.090) for {'activation': 'identity', 'alpha': 0.001}
# 0.612 (+/-0.073) for {'activation': 'identity', 'alpha': 1e-05}
# 0.579 (+/-0.091) for {'activation': 'identity', 'alpha': 1e-06}
# 0.630 (+/-0.054) for {'activation': 'relu', 'alpha': 0.001}
# 0.604 (+/-0.045) for {'activation': 'relu', 'alpha': 1e-05}
# 0.590 (+/-0.035) for {'activation': 'relu', 'alpha': 1e-06}
# 0.551 (+/-0.009) for {'activation': 'logistic', 'alpha': 0.001}
# 0.551 (+/-0.031) for {'activation': 'logistic', 'alpha': 1e-05}
# 0.546 (+/-0.011) for {'activation': 'logistic', 'alpha': 1e-06}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         4
#           1       0.33      0.42      0.37        31
#           2       1.00      0.50      0.67         4
#           3       0.73      0.86      0.79       109
#           4       0.60      0.29      0.39        21
#           5       0.69      0.42      0.52        26
#
# avg / total       0.64      0.65      0.63       195
#
#
# MLPClassifier,student,accuracy,relu,0.001,0.63,0.65
# # Tuning hyper-parameters for accuracy, model SVC
#
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.499 (+/-0.018) for {'C': 1, 'kernel': 'linear'}
# 0.451 (+/-0.009) for {'C': 1, 'kernel': 'poly'}
# 0.495 (+/-0.046) for {'C': 1, 'kernel': 'rbf'}
# 0.457 (+/-0.027) for {'C': 1, 'kernel': 'sigmoid'}
# 0.496 (+/-0.059) for {'C': 10, 'kernel': 'linear'}
# 0.499 (+/-0.027) for {'C': 10, 'kernel': 'poly'}
# 0.520 (+/-0.050) for {'C': 10, 'kernel': 'rbf'}
# 0.480 (+/-0.036) for {'C': 10, 'kernel': 'sigmoid'}
# 0.500 (+/-0.061) for {'C': 100, 'kernel': 'linear'}
# 0.520 (+/-0.070) for {'C': 100, 'kernel': 'poly'}
# 0.539 (+/-0.065) for {'C': 100, 'kernel': 'rbf'}
# 0.453 (+/-0.061) for {'C': 100, 'kernel': 'sigmoid'}
# 0.499 (+/-0.058) for {'C': 1000, 'kernel': 'linear'}
# 0.534 (+/-0.078) for {'C': 1000, 'kernel': 'poly'}
# 0.543 (+/-0.085) for {'C': 1000, 'kernel': 'rbf'}
# 0.424 (+/-0.031) for {'C': 1000, 'kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.58      0.69      0.63       181
#           2       0.48      0.23      0.31       117
#           3       0.43      0.51      0.47       144
#
# avg / total       0.51      0.51      0.49       442
#
#
# SVC,contraceptive,accuracy,1000,rbf,0.54,0.51
# # Tuning hyper-parameters for accuracy, model KNeighborsClassifier
#
# Best parameters set found on development set:
#
# {'n_neighbors': 3, 'weights': 'uniform'}
#
# Grid scores on development set:
#
# 0.442 (+/-0.104) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.442 (+/-0.104) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.483 (+/-0.045) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.456 (+/-0.080) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.464 (+/-0.030) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.462 (+/-0.061) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.472 (+/-0.034) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.459 (+/-0.039) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.469 (+/-0.048) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.460 (+/-0.036) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.473 (+/-0.068) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.477 (+/-0.047) for {'n_neighbors': 30, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.46      0.57      0.51       181
#           2       0.36      0.25      0.29       117
#           3       0.38      0.36      0.37       144
#
# avg / total       0.41      0.42      0.41       442
#
#
# KNeighborsClassifier,contraceptive,accuracy,3,uniform,0.48,0.42
# # Tuning hyper-parameters for accuracy, model RandomForestClassifier
# Best parameters set found on development set:
#
# {'max_depth': 3, 'n_estimators': 30}
#
# Grid scores on development set:
#
# 0.502 (+/-0.042) for {'max_depth': None, 'n_estimators': 10}
# 0.513 (+/-0.072) for {'max_depth': None, 'n_estimators': 30}
# 0.522 (+/-0.064) for {'max_depth': None, 'n_estimators': 50}
# 0.529 (+/-0.064) for {'max_depth': None, 'n_estimators': 100}
# 0.481 (+/-0.116) for {'max_depth': 1, 'n_estimators': 10}
# 0.445 (+/-0.035) for {'max_depth': 1, 'n_estimators': 30}
# 0.451 (+/-0.036) for {'max_depth': 1, 'n_estimators': 50}
# 0.451 (+/-0.015) for {'max_depth': 1, 'n_estimators': 100}
# 0.528 (+/-0.072) for {'max_depth': 3, 'n_estimators': 10}
# 0.549 (+/-0.037) for {'max_depth': 3, 'n_estimators': 30}
# 0.539 (+/-0.069) for {'max_depth': 3, 'n_estimators': 50}
# 0.544 (+/-0.070) for {'max_depth': 3, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.54      0.57      0.56       181
#           2       0.86      0.05      0.10       117
#           3       0.40      0.67      0.50       144
#
# avg / total       0.58      0.47      0.42       442
#
#
# RandomForestClassifier,contraceptive,accuracy,3,30,0.55,0.47
# # Tuning hyper-parameters for accuracy, model MLPClassifier
#
# Best parameters set found on development set:
#
# {'activation': 'relu', 'alpha': 1e-06}
#
# Grid scores on development set:
#
# 0.489 (+/-0.036) for {'activation': 'identity', 'alpha': 0.001}
# 0.494 (+/-0.052) for {'activation': 'identity', 'alpha': 1e-05}
# 0.487 (+/-0.034) for {'activation': 'identity', 'alpha': 1e-06}
# 0.494 (+/-0.046) for {'activation': 'relu', 'alpha': 0.001}
# 0.495 (+/-0.040) for {'activation': 'relu', 'alpha': 1e-05}
# 0.507 (+/-0.046) for {'activation': 'relu', 'alpha': 1e-06}
# 0.442 (+/-0.057) for {'activation': 'logistic', 'alpha': 0.001}
# 0.460 (+/-0.064) for {'activation': 'logistic', 'alpha': 1e-05}
# 0.439 (+/-0.019) for {'activation': 'logistic', 'alpha': 1e-06}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.59      0.64      0.62       181
#           2       0.58      0.34      0.43       117
#           3       0.45      0.56      0.50       144
#
# avg / total       0.54      0.53      0.53       442
#
#
# MLPClassifier,contraceptive,accuracy,relu,1e-06,0.51,0.53
# # Tuning hyper-parameters for accuracy, model SVC
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 1.000 (+/-0.000) for {'C': 1, 'kernel': 'linear'}
# 0.941 (+/-0.046) for {'C': 1, 'kernel': 'poly'}
# 0.976 (+/-0.030) for {'C': 1, 'kernel': 'rbf'}
# 0.965 (+/-0.039) for {'C': 1, 'kernel': 'sigmoid'}
# 1.000 (+/-0.000) for {'C': 10, 'kernel': 'linear'}
# 0.988 (+/-0.024) for {'C': 10, 'kernel': 'poly'}
# 1.000 (+/-0.000) for {'C': 10, 'kernel': 'rbf'}
# 0.988 (+/-0.024) for {'C': 10, 'kernel': 'sigmoid'}
# 1.000 (+/-0.000) for {'C': 100, 'kernel': 'linear'}
# 0.998 (+/-0.008) for {'C': 100, 'kernel': 'poly'}
# 1.000 (+/-0.000) for {'C': 100, 'kernel': 'rbf'}
# 1.000 (+/-0.000) for {'C': 100, 'kernel': 'sigmoid'}
# 1.000 (+/-0.000) for {'C': 1000, 'kernel': 'linear'}
# 0.998 (+/-0.008) for {'C': 1000, 'kernel': 'poly'}
# 1.000 (+/-0.000) for {'C': 1000, 'kernel': 'rbf'}
# 0.992 (+/-0.008) for {'C': 1000, 'kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       155
#           1       1.00      1.00      1.00        57
#
# avg / total       1.00      1.00      1.00       212
#
#
# SVC,autism,accuracy,1,linear,1.00,1.00
# # Tuning hyper-parameters for accuracy, model KNeighborsClassifier
#
# Best parameters set found on development set:
#
# {'n_neighbors': 3, 'weights': 'distance'}
#
# Grid scores on development set:
#
# 0.941 (+/-0.035) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.941 (+/-0.035) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.963 (+/-0.033) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.967 (+/-0.033) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.961 (+/-0.024) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.965 (+/-0.024) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.965 (+/-0.021) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.965 (+/-0.038) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.959 (+/-0.037) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.967 (+/-0.035) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.957 (+/-0.030) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.967 (+/-0.020) for {'n_neighbors': 30, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.97      0.96      0.97       155
#           1       0.90      0.93      0.91        57
#
# avg / total       0.95      0.95      0.95       212
#
#
# KNeighborsClassifier,autism,accuracy,3,distance,0.97,0.95
# # Tuning hyper-parameters for accuracy, model RandomForestClassifier
#
# Best parameters set found on development set:
#
# {'max_depth': None, 'n_estimators': 30}
#
# Grid scores on development set:
#
# 0.998 (+/-0.008) for {'max_depth': None, 'n_estimators': 10}
# 1.000 (+/-0.000) for {'max_depth': None, 'n_estimators': 30}
# 1.000 (+/-0.000) for {'max_depth': None, 'n_estimators': 50}
# 1.000 (+/-0.000) for {'max_depth': None, 'n_estimators': 100}
# 0.978 (+/-0.061) for {'max_depth': 1, 'n_estimators': 10}
# 0.947 (+/-0.065) for {'max_depth': 1, 'n_estimators': 30}
# 0.941 (+/-0.074) for {'max_depth': 1, 'n_estimators': 50}
# 0.949 (+/-0.013) for {'max_depth': 1, 'n_estimators': 100}
# 1.000 (+/-0.000) for {'max_depth': 3, 'n_estimators': 10}
# 0.990 (+/-0.040) for {'max_depth': 3, 'n_estimators': 30}
# 1.000 (+/-0.000) for {'max_depth': 3, 'n_estimators': 50}
# 1.000 (+/-0.000) for {'max_depth': 3, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       155
#           1       1.00      1.00      1.00        57
#
# avg / total       1.00      1.00      1.00       212
#
#
# RandomForestClassifier,autism,accuracy,None,30,1.00,1.00
# # Tuning hyper-parameters for accuracy, model MLPClassifier
#
# Best parameters set found on development set:
#
# {'activation': 'relu', 'alpha': 0.001}
#
# Grid scores on development set:
#
# 0.945 (+/-0.046) for {'activation': 'identity', 'alpha': 0.001}
# 0.949 (+/-0.036) for {'activation': 'identity', 'alpha': 1e-05}
# 0.949 (+/-0.048) for {'activation': 'identity', 'alpha': 1e-06}
# 0.955 (+/-0.049) for {'activation': 'relu', 'alpha': 0.001}
# 0.951 (+/-0.058) for {'activation': 'relu', 'alpha': 1e-05}
# 0.949 (+/-0.062) for {'activation': 'relu', 'alpha': 1e-06}
# 0.955 (+/-0.040) for {'activation': 'logistic', 'alpha': 0.001}
# 0.953 (+/-0.052) for {'activation': 'logistic', 'alpha': 1e-05}
# 0.955 (+/-0.042) for {'activation': 'logistic', 'alpha': 1e-06}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.99      0.97      0.98       155
#           1       0.93      0.98      0.96        57
#
# avg / total       0.98      0.98      0.98       212
#
#
# MLPClassifier,autism,accuracy,relu,0.001,0.96,0.98
# # Tuning hyper-parameters for accuracy, model SVC
#
# Best parameters set found on development set:
#
# {'C': 10, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.474 (+/-0.130) for {'C': 1, 'kernel': 'linear'}
# 0.589 (+/-0.012) for {'C': 1, 'kernel': 'poly'}
# 0.909 (+/-0.124) for {'C': 1, 'kernel': 'rbf'}
# 0.589 (+/-0.012) for {'C': 1, 'kernel': 'sigmoid'}
# 0.451 (+/-0.178) for {'C': 10, 'kernel': 'linear'}
# 0.829 (+/-0.045) for {'C': 10, 'kernel': 'poly'}
# 0.989 (+/-0.028) for {'C': 10, 'kernel': 'rbf'}
# 0.440 (+/-0.124) for {'C': 10, 'kernel': 'sigmoid'}
# 0.526 (+/-0.217) for {'C': 100, 'kernel': 'linear'}
# 0.920 (+/-0.064) for {'C': 100, 'kernel': 'poly'}
# 0.983 (+/-0.046) for {'C': 100, 'kernel': 'rbf'}
# 0.314 (+/-0.122) for {'C': 100, 'kernel': 'sigmoid'}
# 0.451 (+/-0.178) for {'C': 1000, 'kernel': 'linear'}
# 0.966 (+/-0.066) for {'C': 1000, 'kernel': 'poly'}
# 0.983 (+/-0.046) for {'C': 1000, 'kernel': 'rbf'}
# 0.331 (+/-0.191) for {'C': 1000, 'kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        35
#           1       1.00      1.00      1.00        40
#
# avg / total       1.00      1.00      1.00        75
#
#
# SVC,bankruptcy,accuracy,10,rbf,0.99,1.00
# # Tuning hyper-parameters for accuracy, model KNeighborsClassifier
#
# Best parameters set found on development set:
#
# {'n_neighbors': 1, 'weights': 'uniform'}
#
# Grid scores on development set:
#
# 0.971 (+/-0.051) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.971 (+/-0.051) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.943 (+/-0.103) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.949 (+/-0.092) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.920 (+/-0.132) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.926 (+/-0.138) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.806 (+/-0.052) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.937 (+/-0.093) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.794 (+/-0.126) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.926 (+/-0.124) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.423 (+/-0.037) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.743 (+/-0.179) for {'n_neighbors': 30, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96        35
#           1       1.00      0.93      0.96        40
#
# avg / total       0.96      0.96      0.96        75
#
#
# KNeighborsClassifier,bankruptcy,accuracy,1,uniform,0.97,0.96
# # Tuning hyper-parameters for accuracy, model RandomForestClassifier
# Best parameters set found on development set:
#
# {'max_depth': None, 'n_estimators': 50}
#
# Grid scores on development set:
#
# 0.989 (+/-0.028) for {'max_depth': None, 'n_estimators': 10}
# 0.994 (+/-0.022) for {'max_depth': None, 'n_estimators': 30}
# 1.000 (+/-0.000) for {'max_depth': None, 'n_estimators': 50}
# 0.994 (+/-0.022) for {'max_depth': None, 'n_estimators': 100}
# 0.897 (+/-0.198) for {'max_depth': 1, 'n_estimators': 10}
# 0.891 (+/-0.165) for {'max_depth': 1, 'n_estimators': 30}
# 0.920 (+/-0.096) for {'max_depth': 1, 'n_estimators': 50}
# 0.914 (+/-0.127) for {'max_depth': 1, 'n_estimators': 100}
# 0.977 (+/-0.068) for {'max_depth': 3, 'n_estimators': 10}
# 0.994 (+/-0.022) for {'max_depth': 3, 'n_estimators': 30}
# 0.989 (+/-0.045) for {'max_depth': 3, 'n_estimators': 50}
# 0.994 (+/-0.022) for {'max_depth': 3, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        35
#           1       1.00      1.00      1.00        40
#
# avg / total       1.00      1.00      1.00        75
#
#
# RandomForestClassifier,bankruptcy,accuracy,None,50,1.00,1.00
# # Tuning hyper-parameters for accuracy, model MLPClassifier
#
# Best parameters set found on development set:
#
# {'activation': 'relu', 'alpha': 1e-06}
#
# Grid scores on development set:
#
# 0.491 (+/-0.207) for {'activation': 'identity', 'alpha': 0.001}
# 0.474 (+/-0.194) for {'activation': 'identity', 'alpha': 1e-05}
# 0.480 (+/-0.199) for {'activation': 'identity', 'alpha': 1e-06}
# 0.840 (+/-0.203) for {'activation': 'relu', 'alpha': 0.001}
# 0.840 (+/-0.135) for {'activation': 'relu', 'alpha': 1e-05}
# 0.851 (+/-0.128) for {'activation': 'relu', 'alpha': 1e-06}
# 0.571 (+/-0.071) for {'activation': 'logistic', 'alpha': 0.001}
# 0.589 (+/-0.012) for {'activation': 'logistic', 'alpha': 1e-05}
# 0.571 (+/-0.071) for {'activation': 'logistic', 'alpha': 1e-06}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.97      0.83      0.89        35
#           1       0.87      0.97      0.92        40
#
# avg / total       0.91      0.91      0.91        75
#
#
# MLPClassifier,bankruptcy,accuracy,relu,1e-06,0.85,0.91
# # Tuning hyper-parameters for accuracy, model SVC
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.973 (+/-0.038) for {'C': 1, 'kernel': 'linear'}
# 0.867 (+/-0.083) for {'C': 1, 'kernel': 'poly'}
# 0.971 (+/-0.035) for {'C': 1, 'kernel': 'rbf'}
# 0.967 (+/-0.032) for {'C': 1, 'kernel': 'sigmoid'}
# 0.973 (+/-0.038) for {'C': 10, 'kernel': 'linear'}
# 0.937 (+/-0.036) for {'C': 10, 'kernel': 'poly'}
# 0.969 (+/-0.034) for {'C': 10, 'kernel': 'rbf'}
# 0.973 (+/-0.038) for {'C': 10, 'kernel': 'sigmoid'}
# 0.961 (+/-0.024) for {'C': 100, 'kernel': 'linear'}
# 0.961 (+/-0.020) for {'C': 100, 'kernel': 'poly'}
# 0.969 (+/-0.029) for {'C': 100, 'kernel': 'rbf'}
# 0.973 (+/-0.038) for {'C': 100, 'kernel': 'sigmoid'}
# 0.961 (+/-0.024) for {'C': 1000, 'kernel': 'linear'}
# 0.959 (+/-0.018) for {'C': 1000, 'kernel': 'poly'}
# 0.945 (+/-0.042) for {'C': 1000, 'kernel': 'rbf'}
# 0.953 (+/-0.021) for {'C': 1000, 'kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           2       0.96      0.95      0.95       135
#           4       0.91      0.92      0.91        75
#
# avg / total       0.94      0.94      0.94       210
#
#
# SVC,breast_cancer,accuracy,1,linear,0.97,0.94
# # Tuning hyper-parameters for accuracy, model KNeighborsClassifier
#
# Best parameters set found on development set:
#
# {'n_neighbors': 10, 'weights': 'distance'}
#
# Grid scores on development set:
#
# 0.951 (+/-0.028) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.951 (+/-0.028) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.965 (+/-0.044) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.965 (+/-0.044) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.963 (+/-0.027) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.963 (+/-0.027) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.963 (+/-0.030) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.967 (+/-0.030) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.963 (+/-0.030) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.969 (+/-0.031) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.955 (+/-0.025) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.957 (+/-0.020) for {'n_neighbors': 30, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           2       0.96      0.96      0.96       135
#           4       0.92      0.92      0.92        75
#
# avg / total       0.94      0.94      0.94       210
#
#
# KNeighborsClassifier,breast_cancer,accuracy,10,distance,0.97,0.94
# # Tuning hyper-parameters for accuracy, model RandomForestClassifier
#
# Best parameters set found on development set:
#
# {'max_depth': 3, 'n_estimators': 10}
#
# Grid scores on development set:
#
# 0.959 (+/-0.034) for {'max_depth': None, 'n_estimators': 10}
# 0.955 (+/-0.017) for {'max_depth': None, 'n_estimators': 30}
# 0.963 (+/-0.033) for {'max_depth': None, 'n_estimators': 50}
# 0.961 (+/-0.030) for {'max_depth': None, 'n_estimators': 100}
# 0.935 (+/-0.071) for {'max_depth': 1, 'n_estimators': 10}
# 0.955 (+/-0.017) for {'max_depth': 1, 'n_estimators': 30}
# 0.957 (+/-0.024) for {'max_depth': 1, 'n_estimators': 50}
# 0.955 (+/-0.021) for {'max_depth': 1, 'n_estimators': 100}
# 0.967 (+/-0.008) for {'max_depth': 3, 'n_estimators': 10}
# 0.967 (+/-0.027) for {'max_depth': 3, 'n_estimators': 30}
# 0.963 (+/-0.016) for {'max_depth': 3, 'n_estimators': 50}
# 0.959 (+/-0.022) for {'max_depth': 3, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           2       0.98      0.95      0.96       135
#           4       0.91      0.96      0.94        75
#
# avg / total       0.95      0.95      0.95       210
#
#
# RandomForestClassifier,breast_cancer,accuracy,3,10,0.97,0.95
# # Tuning hyper-parameters for accuracy, model MLPClassifier
#
# Best parameters set found on development set:
#
# {'activation': 'logistic', 'alpha': 0.001}
#
# Grid scores on development set:
#
# 0.959 (+/-0.026) for {'activation': 'identity', 'alpha': 0.001}
# 0.963 (+/-0.027) for {'activation': 'identity', 'alpha': 1e-05}
# 0.961 (+/-0.023) for {'activation': 'identity', 'alpha': 1e-06}
# 0.957 (+/-0.040) for {'activation': 'relu', 'alpha': 0.001}
# 0.963 (+/-0.027) for {'activation': 'relu', 'alpha': 1e-05}
# 0.963 (+/-0.027) for {'activation': 'relu', 'alpha': 1e-06}
# 0.969 (+/-0.026) for {'activation': 'logistic', 'alpha': 0.001}
# 0.967 (+/-0.024) for {'activation': 'logistic', 'alpha': 1e-05}
# 0.969 (+/-0.026) for {'activation': 'logistic', 'alpha': 1e-06}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           2       0.96      0.95      0.95       135
#           4       0.91      0.92      0.91        75
#
# avg / total       0.94      0.94      0.94       210
#
#
# MLPClassifier,breast_cancer,accuracy,logistic,0.001,0.97,0.94
# # Tuning hyper-parameters for accuracy, model SVC
#
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'poly'}
#
# Grid scores on development set:
#
# 0.833 (+/-0.113) for {'C': 1, 'kernel': 'linear'}
# 0.619 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.814 (+/-0.169) for {'C': 1, 'kernel': 'rbf'}
# 0.829 (+/-0.152) for {'C': 1, 'kernel': 'sigmoid'}
# 0.824 (+/-0.123) for {'C': 10, 'kernel': 'linear'}
# 0.843 (+/-0.137) for {'C': 10, 'kernel': 'poly'}
# 0.848 (+/-0.111) for {'C': 10, 'kernel': 'rbf'}
# 0.829 (+/-0.160) for {'C': 10, 'kernel': 'sigmoid'}
# 0.838 (+/-0.110) for {'C': 100, 'kernel': 'linear'}
# 0.838 (+/-0.097) for {'C': 100, 'kernel': 'poly'}
# 0.838 (+/-0.097) for {'C': 100, 'kernel': 'rbf'}
# 0.838 (+/-0.129) for {'C': 100, 'kernel': 'sigmoid'}
# 0.829 (+/-0.110) for {'C': 1000, 'kernel': 'linear'}
# 0.852 (+/-0.082) for {'C': 1000, 'kernel': 'poly'}
# 0.786 (+/-0.100) for {'C': 1000, 'kernel': 'rbf'}
# 0.762 (+/-0.124) for {'C': 1000, 'kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.93      0.87      0.90        61
#           2       0.76      0.86      0.81        29
#
# avg / total       0.87      0.87      0.87        90
#
#
# SVC,horse,accuracy,1000,poly,0.85,0.87
# # Tuning hyper-parameters for accuracy, model KNeighborsClassifier
#
# Best parameters set found on development set:
#
# {'n_neighbors': 30, 'weights': 'distance'}
#
# Grid scores on development set:
#
# 0.786 (+/-0.100) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.786 (+/-0.100) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.824 (+/-0.146) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.838 (+/-0.126) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.838 (+/-0.126) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.848 (+/-0.123) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.852 (+/-0.092) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.852 (+/-0.106) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.848 (+/-0.098) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.852 (+/-0.097) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.852 (+/-0.110) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.862 (+/-0.110) for {'n_neighbors': 30, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.85      0.93      0.89        61
#           2       0.83      0.66      0.73        29
#
# avg / total       0.84      0.84      0.84        90
#
#
# KNeighborsClassifier,horse,accuracy,30,distance,0.86,0.84
# # Tuning hyper-parameters for accuracy, model RandomForestClassifier
# Best parameters set found on development set:
#
# {'max_depth': None, 'n_estimators': 10}
#
# Grid scores on development set:
#
# 0.852 (+/-0.092) for {'max_depth': None, 'n_estimators': 10}
# 0.848 (+/-0.098) for {'max_depth': None, 'n_estimators': 30}
# 0.838 (+/-0.092) for {'max_depth': None, 'n_estimators': 50}
# 0.833 (+/-0.095) for {'max_depth': None, 'n_estimators': 100}
# 0.733 (+/-0.133) for {'max_depth': 1, 'n_estimators': 10}
# 0.757 (+/-0.070) for {'max_depth': 1, 'n_estimators': 30}
# 0.786 (+/-0.128) for {'max_depth': 1, 'n_estimators': 50}
# 0.767 (+/-0.097) for {'max_depth': 1, 'n_estimators': 100}
# 0.819 (+/-0.123) for {'max_depth': 3, 'n_estimators': 10}
# 0.805 (+/-0.114) for {'max_depth': 3, 'n_estimators': 30}
# 0.819 (+/-0.130) for {'max_depth': 3, 'n_estimators': 50}
# 0.848 (+/-0.077) for {'max_depth': 3, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.85      0.92      0.88        61
#           2       0.79      0.66      0.72        29
#
# avg / total       0.83      0.83      0.83        90
#
#
# RandomForestClassifier,horse,accuracy,None,10,0.85,0.83
# # Tuning hyper-parameters for accuracy, model MLPClassifier
#
# Best parameters set found on development set:
#
# {'activation': 'logistic', 'alpha': 1e-06}
#
# Grid scores on development set:
#
# 0.819 (+/-0.123) for {'activation': 'identity', 'alpha': 0.001}
# 0.810 (+/-0.131) for {'activation': 'identity', 'alpha': 1e-05}
# 0.810 (+/-0.131) for {'activation': 'identity', 'alpha': 1e-06}
# 0.814 (+/-0.122) for {'activation': 'relu', 'alpha': 0.001}
# 0.829 (+/-0.133) for {'activation': 'relu', 'alpha': 1e-05}
# 0.810 (+/-0.109) for {'activation': 'relu', 'alpha': 1e-06}
# 0.824 (+/-0.093) for {'activation': 'logistic', 'alpha': 0.001}
# 0.800 (+/-0.093) for {'activation': 'logistic', 'alpha': 1e-05}
# 0.833 (+/-0.052) for {'activation': 'logistic', 'alpha': 1e-06}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.86      0.97      0.91        61
#           2       0.90      0.66      0.76        29
#
# avg / total       0.87      0.87      0.86        90
#
#
# MLPClassifier,horse,accuracy,logistic,1e-06,0.83,0.87
# # Tuning hyper-parameters for accuracy, model SVC
#
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.793 (+/-0.013) for {'C': 1, 'kernel': 'linear'}
# 0.789 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.836 (+/-0.010) for {'C': 1, 'kernel': 'rbf'}
# 0.789 (+/-0.000) for {'C': 1, 'kernel': 'sigmoid'}
# 0.798 (+/-0.024) for {'C': 10, 'kernel': 'linear'}
# 0.847 (+/-0.019) for {'C': 10, 'kernel': 'poly'}
# 0.947 (+/-0.019) for {'C': 10, 'kernel': 'rbf'}
# 0.772 (+/-0.046) for {'C': 10, 'kernel': 'sigmoid'}
# 0.797 (+/-0.025) for {'C': 100, 'kernel': 'linear'}
# 0.905 (+/-0.027) for {'C': 100, 'kernel': 'poly'}
# 0.966 (+/-0.025) for {'C': 100, 'kernel': 'rbf'}
# 0.685 (+/-0.060) for {'C': 100, 'kernel': 'sigmoid'}
# 0.797 (+/-0.023) for {'C': 1000, 'kernel': 'linear'}
# 0.938 (+/-0.012) for {'C': 1000, 'kernel': 'poly'}
# 0.966 (+/-0.026) for {'C': 1000, 'kernel': 'rbf'}
# 0.634 (+/-0.045) for {'C': 1000, 'kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97       556
#           1       0.96      0.87      0.91       194
#
# avg / total       0.96      0.96      0.96       750
#
#
# SVC,hr,accuracy,1000,rbf,0.97,0.96
# # Tuning hyper-parameters for accuracy, model KNeighborsClassifier
#
# Best parameters set found on development set:
#
# {'n_neighbors': 1, 'weights': 'uniform'}
#
# Grid scores on development set:
#
# 0.954 (+/-0.012) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.954 (+/-0.012) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.947 (+/-0.014) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.951 (+/-0.011) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.948 (+/-0.019) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.951 (+/-0.017) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.947 (+/-0.021) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.947 (+/-0.022) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.946 (+/-0.023) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.949 (+/-0.020) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.929 (+/-0.012) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.939 (+/-0.016) for {'n_neighbors': 30, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96       556
#           1       0.93      0.84      0.88       194
#
# avg / total       0.94      0.94      0.94       750
#
#
# KNeighborsClassifier,hr,accuracy,1,uniform,0.95,0.94
# # Tuning hyper-parameters for accuracy, model RandomForestClassifier
#
# Best parameters set found on development set:
#
# {'max_depth': None, 'n_estimators': 30}
#
# Grid scores on development set:
#
# 0.991 (+/-0.007) for {'max_depth': None, 'n_estimators': 10}
# 0.994 (+/-0.010) for {'max_depth': None, 'n_estimators': 30}
# 0.993 (+/-0.011) for {'max_depth': None, 'n_estimators': 50}
# 0.993 (+/-0.008) for {'max_depth': None, 'n_estimators': 100}
# 0.850 (+/-0.047) for {'max_depth': 1, 'n_estimators': 10}
# 0.855 (+/-0.063) for {'max_depth': 1, 'n_estimators': 30}
# 0.863 (+/-0.032) for {'max_depth': 1, 'n_estimators': 50}
# 0.869 (+/-0.027) for {'max_depth': 1, 'n_estimators': 100}
# 0.951 (+/-0.060) for {'max_depth': 3, 'n_estimators': 10}
# 0.955 (+/-0.041) for {'max_depth': 3, 'n_estimators': 30}
# 0.960 (+/-0.017) for {'max_depth': 3, 'n_estimators': 50}
# 0.956 (+/-0.027) for {'max_depth': 3, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99       556
#           1       1.00      0.97      0.98       194
#
# avg / total       0.99      0.99      0.99       750
#
#
# RandomForestClassifier,hr,accuracy,None,30,0.99,0.99
# # Tuning hyper-parameters for accuracy, model MLPClassifier
#
# Best parameters set found on development set:
#
# {'activation': 'relu', 'alpha': 1e-06}
#
# Grid scores on development set:
#
# 0.795 (+/-0.046) for {'activation': 'identity', 'alpha': 0.001}
# 0.793 (+/-0.048) for {'activation': 'identity', 'alpha': 1e-05}
# 0.793 (+/-0.043) for {'activation': 'identity', 'alpha': 1e-06}
# 0.962 (+/-0.020) for {'activation': 'relu', 'alpha': 0.001}
# 0.962 (+/-0.018) for {'activation': 'relu', 'alpha': 1e-05}
# 0.965 (+/-0.019) for {'activation': 'relu', 'alpha': 1e-06}
# 0.797 (+/-0.049) for {'activation': 'logistic', 'alpha': 0.001}
# 0.795 (+/-0.047) for {'activation': 'logistic', 'alpha': 1e-05}
# 0.797 (+/-0.033) for {'activation': 'logistic', 'alpha': 1e-06}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98       556
#           1       0.97      0.90      0.93       194
#
# avg / total       0.97      0.97      0.97       750
#
#
# MLPClassifier,hr,accuracy,relu,1e-06,0.97,0.97
# # Tuning hyper-parameters for accuracy, model SVC
#
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.543 (+/-0.163) for {'C': 1, 'kernel': 'linear'}
# 0.448 (+/-0.128) for {'C': 1, 'kernel': 'poly'}
# 0.457 (+/-0.152) for {'C': 1, 'kernel': 'rbf'}
# 0.429 (+/-0.137) for {'C': 1, 'kernel': 'sigmoid'}
# 0.524 (+/-0.172) for {'C': 10, 'kernel': 'linear'}
# 0.524 (+/-0.155) for {'C': 10, 'kernel': 'poly'}
# 0.543 (+/-0.156) for {'C': 10, 'kernel': 'rbf'}
# 0.543 (+/-0.144) for {'C': 10, 'kernel': 'sigmoid'}
# 0.505 (+/-0.211) for {'C': 100, 'kernel': 'linear'}
# 0.514 (+/-0.171) for {'C': 100, 'kernel': 'poly'}
# 0.486 (+/-0.174) for {'C': 100, 'kernel': 'rbf'}
# 0.505 (+/-0.087) for {'C': 100, 'kernel': 'sigmoid'}
# 0.505 (+/-0.211) for {'C': 1000, 'kernel': 'linear'}
# 0.514 (+/-0.199) for {'C': 1000, 'kernel': 'poly'}
# 0.571 (+/-0.200) for {'C': 1000, 'kernel': 'rbf'}
# 0.390 (+/-0.157) for {'C': 1000, 'kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.32      0.67      0.43         9
#           2       0.55      0.33      0.41        18
#           3       0.69      0.58      0.63        19
#
# avg / total       0.56      0.50      0.51        46
#
#
# SVC,english,accuracy,1000,rbf,0.57,0.50
# # Tuning hyper-parameters for accuracy, model KNeighborsClassifier
#
# Best parameters set found on development set:
#
# {'n_neighbors': 3, 'weights': 'distance'}
#
# Grid scores on development set:
#
# 0.543 (+/-0.223) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.543 (+/-0.223) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.505 (+/-0.172) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.581 (+/-0.172) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.495 (+/-0.116) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.581 (+/-0.146) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.495 (+/-0.202) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.581 (+/-0.185) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.543 (+/-0.216) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.562 (+/-0.212) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.438 (+/-0.117) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.543 (+/-0.182) for {'n_neighbors': 30, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.47      0.78      0.58         9
#           2       0.60      0.50      0.55        18
#           3       0.81      0.68      0.74        19
#
# avg / total       0.66      0.63      0.63        46
#
#
# KNeighborsClassifier,english,accuracy,3,distance,0.58,0.63
# # Tuning hyper-parameters for accuracy, model RandomForestClassifier
# Best parameters set found on development set:
#
# {'max_depth': None, 'n_estimators': 50}
#
# Grid scores on development set:
#
# 0.495 (+/-0.289) for {'max_depth': None, 'n_estimators': 10}
# 0.552 (+/-0.177) for {'max_depth': None, 'n_estimators': 30}
# 0.581 (+/-0.204) for {'max_depth': None, 'n_estimators': 50}
# 0.571 (+/-0.214) for {'max_depth': None, 'n_estimators': 100}
# 0.419 (+/-0.069) for {'max_depth': 1, 'n_estimators': 10}
# 0.438 (+/-0.159) for {'max_depth': 1, 'n_estimators': 30}
# 0.448 (+/-0.135) for {'max_depth': 1, 'n_estimators': 50}
# 0.457 (+/-0.154) for {'max_depth': 1, 'n_estimators': 100}
# 0.533 (+/-0.141) for {'max_depth': 3, 'n_estimators': 10}
# 0.552 (+/-0.217) for {'max_depth': 3, 'n_estimators': 30}
# 0.533 (+/-0.146) for {'max_depth': 3, 'n_estimators': 50}
# 0.533 (+/-0.137) for {'max_depth': 3, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.47      0.78      0.58         9
#           2       0.69      0.50      0.58        18
#           3       0.83      0.79      0.81        19
#
# avg / total       0.71      0.67      0.68        46
#
#
# RandomForestClassifier,english,accuracy,None,50,0.58,0.67
# # Tuning hyper-parameters for accuracy, model MLPClassifier
#
# Best parameters set found on development set:
#
# {'activation': 'identity', 'alpha': 0.001}
#
# Grid scores on development set:
#
# 0.514 (+/-0.133) for {'activation': 'identity', 'alpha': 0.001}
# 0.505 (+/-0.113) for {'activation': 'identity', 'alpha': 1e-05}
# 0.505 (+/-0.076) for {'activation': 'identity', 'alpha': 1e-06}
# 0.514 (+/-0.146) for {'activation': 'relu', 'alpha': 0.001}
# 0.514 (+/-0.146) for {'activation': 'relu', 'alpha': 1e-05}
# 0.514 (+/-0.192) for {'activation': 'relu', 'alpha': 1e-06}
# 0.381 (+/-0.032) for {'activation': 'logistic', 'alpha': 0.001}
# 0.381 (+/-0.032) for {'activation': 'logistic', 'alpha': 1e-05}
# 0.324 (+/-0.117) for {'activation': 'logistic', 'alpha': 1e-06}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           1       0.38      0.67      0.48         9
#           2       0.53      0.44      0.48        18
#           3       0.60      0.47      0.53        19
#
# avg / total       0.53      0.50      0.50        46
#
#
# MLPClassifier,english,accuracy,identity,0.001,0.51,0.50
# # Tuning hyper-parameters for accuracy, model SVC
#
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.838 (+/-0.042) for {'C': 1, 'kernel': 'linear'}
# 0.833 (+/-0.040) for {'C': 1, 'kernel': 'poly'}
# 0.832 (+/-0.054) for {'C': 1, 'kernel': 'rbf'}
# 0.824 (+/-0.062) for {'C': 1, 'kernel': 'sigmoid'}
# 0.844 (+/-0.049) for {'C': 10, 'kernel': 'linear'}
# 0.859 (+/-0.050) for {'C': 10, 'kernel': 'poly'}
# 0.876 (+/-0.042) for {'C': 10, 'kernel': 'rbf'}
# 0.823 (+/-0.061) for {'C': 10, 'kernel': 'sigmoid'}
# 0.847 (+/-0.045) for {'C': 100, 'kernel': 'linear'}
# 0.886 (+/-0.043) for {'C': 100, 'kernel': 'poly'}
# 0.894 (+/-0.039) for {'C': 100, 'kernel': 'rbf'}
# 0.785 (+/-0.069) for {'C': 100, 'kernel': 'sigmoid'}
# 0.846 (+/-0.048) for {'C': 1000, 'kernel': 'linear'}
# 0.883 (+/-0.041) for {'C': 1000, 'kernel': 'poly'}
# 0.883 (+/-0.041) for {'C': 1000, 'kernel': 'rbf'}
# 0.761 (+/-0.039) for {'C': 1000, 'kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.88      0.89      0.89       204
#           1       0.74      0.76      0.75        33
#           2       0.85      0.83      0.84       169
#
# avg / total       0.86      0.86      0.86       406
#
#
# SVC,phishing,accuracy,100,rbf,0.89,0.86
# # Tuning hyper-parameters for accuracy, model KNeighborsClassifier
#
# Best parameters set found on development set:
#
# {'n_neighbors': 3, 'weights': 'distance'}
#
# Grid scores on development set:
#
# 0.859 (+/-0.039) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.859 (+/-0.039) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.874 (+/-0.031) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.879 (+/-0.034) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.857 (+/-0.045) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.867 (+/-0.053) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.857 (+/-0.022) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.870 (+/-0.039) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.854 (+/-0.036) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.872 (+/-0.043) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.822 (+/-0.047) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.860 (+/-0.031) for {'n_neighbors': 30, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.86      0.87      0.86       204
#           1       0.85      0.70      0.77        33
#           2       0.83      0.85      0.84       169
#
# avg / total       0.85      0.85      0.85       406
#
#
# KNeighborsClassifier,phishing,accuracy,3,distance,0.88,0.85
# # Tuning hyper-parameters for accuracy, model RandomForestClassifier
#
# Best parameters set found on development set:
#
# {'max_depth': None, 'n_estimators': 50}
#
# Grid scores on development set:
#
# 0.900 (+/-0.040) for {'max_depth': None, 'n_estimators': 10}
# 0.902 (+/-0.047) for {'max_depth': None, 'n_estimators': 30}
# 0.903 (+/-0.043) for {'max_depth': None, 'n_estimators': 50}
# 0.903 (+/-0.044) for {'max_depth': None, 'n_estimators': 100}
# 0.810 (+/-0.095) for {'max_depth': 1, 'n_estimators': 10}
# 0.839 (+/-0.057) for {'max_depth': 1, 'n_estimators': 30}
# 0.836 (+/-0.029) for {'max_depth': 1, 'n_estimators': 50}
# 0.831 (+/-0.038) for {'max_depth': 1, 'n_estimators': 100}
# 0.846 (+/-0.025) for {'max_depth': 3, 'n_estimators': 10}
# 0.864 (+/-0.033) for {'max_depth': 3, 'n_estimators': 30}
# 0.855 (+/-0.042) for {'max_depth': 3, 'n_estimators': 50}
# 0.853 (+/-0.048) for {'max_depth': 3, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.87      0.92      0.89       204
#           1       0.90      0.85      0.88        33
#           2       0.89      0.83      0.86       169
#
# avg / total       0.88      0.88      0.88       406
#
#
# RandomForestClassifier,phishing,accuracy,None,50,0.90,0.88
# # Tuning hyper-parameters for accuracy, model MLPClassifier
#
# Best parameters set found on development set:
#
# {'activation': 'relu', 'alpha': 0.001}
#
# Grid scores on development set:
#
# 0.838 (+/-0.040) for {'activation': 'identity', 'alpha': 0.001}
# 0.834 (+/-0.041) for {'activation': 'identity', 'alpha': 1e-05}
# 0.839 (+/-0.041) for {'activation': 'identity', 'alpha': 1e-06}
# 0.871 (+/-0.025) for {'activation': 'relu', 'alpha': 0.001}
# 0.861 (+/-0.043) for {'activation': 'relu', 'alpha': 1e-05}
# 0.866 (+/-0.031) for {'activation': 'relu', 'alpha': 1e-06}
# 0.839 (+/-0.035) for {'activation': 'logistic', 'alpha': 0.001}
# 0.836 (+/-0.039) for {'activation': 'logistic', 'alpha': 1e-05}
# 0.837 (+/-0.038) for {'activation': 'logistic', 'alpha': 1e-06}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.86      0.87      0.86       204
#           1       0.71      0.36      0.48        33
#           2       0.81      0.87      0.84       169
#
# avg / total       0.83      0.83      0.82       406
#
#
# MLPClassifier,phishing,accuracy,relu,0.001,0.87,0.83
# # Tuning hyper-parameters for accuracy, model SVC
#
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.518 (+/-0.019) for {'C': 1, 'kernel': 'linear'}
# 0.457 (+/-0.002) for {'C': 1, 'kernel': 'poly'}
# 0.499 (+/-0.010) for {'C': 1, 'kernel': 'rbf'}
# 0.467 (+/-0.003) for {'C': 1, 'kernel': 'sigmoid'}
# 0.521 (+/-0.027) for {'C': 10, 'kernel': 'linear'}
# 0.457 (+/-0.002) for {'C': 10, 'kernel': 'poly'}
# 0.521 (+/-0.022) for {'C': 10, 'kernel': 'rbf'}
# 0.518 (+/-0.021) for {'C': 10, 'kernel': 'sigmoid'}
# 0.521 (+/-0.033) for {'C': 100, 'kernel': 'linear'}
# 0.475 (+/-0.008) for {'C': 100, 'kernel': 'poly'}
# 0.533 (+/-0.020) for {'C': 100, 'kernel': 'rbf'}
# 0.521 (+/-0.027) for {'C': 100, 'kernel': 'sigmoid'}
# 0.522 (+/-0.031) for {'C': 1000, 'kernel': 'linear'}
# 0.519 (+/-0.018) for {'C': 1000, 'kernel': 'poly'}
# 0.546 (+/-0.027) for {'C': 1000, 'kernel': 'rbf'}
# 0.504 (+/-0.047) for {'C': 1000, 'kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           3       0.00      0.00      0.00         9
#           4       0.00      0.00      0.00        60
#           5       0.60      0.45      0.51       458
#           6       0.49      0.81      0.61       630
#           7       0.51      0.18      0.27       267
#           8       0.00      0.00      0.00        46
#           9       0.00      0.00      0.00         0
#
# avg / total       0.49      0.52      0.47      1470
#
#
# SVC,wine,accuracy,1000,rbf,0.55,0.52
# # Tuning hyper-parameters for accuracy, model KNeighborsClassifier
# Best parameters set found on development set:
#
# {'n_neighbors': 30, 'weights': 'distance'}
#
# Grid scores on development set:
#
# 0.612 (+/-0.015) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.612 (+/-0.015) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.536 (+/-0.017) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.611 (+/-0.037) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.545 (+/-0.018) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.623 (+/-0.032) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.539 (+/-0.030) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.623 (+/-0.032) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.534 (+/-0.046) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.626 (+/-0.027) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.542 (+/-0.028) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.645 (+/-0.034) for {'n_neighbors': 30, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           3       0.00      0.00      0.00         9
#           4       1.00      0.08      0.15        60
#           5       0.72      0.61      0.66       458
#           6       0.61      0.82      0.70       630
#           7       0.64      0.53      0.58       267
#           8       1.00      0.33      0.49        46
#
# avg / total       0.68      0.65      0.63      1470
#
#
# KNeighborsClassifier,wine,accuracy,30,distance,0.65,0.65
# # Tuning hyper-parameters for accuracy, model RandomForestClassifier
#
# Best parameters set found on development set:
#
# {'max_depth': None, 'n_estimators': 50}
#
# Grid scores on development set:
#
# 0.642 (+/-0.020) for {'max_depth': None, 'n_estimators': 10}
# 0.655 (+/-0.035) for {'max_depth': None, 'n_estimators': 30}
# 0.658 (+/-0.014) for {'max_depth': None, 'n_estimators': 50}
# 0.656 (+/-0.026) for {'max_depth': None, 'n_estimators': 100}
# 0.457 (+/-0.002) for {'max_depth': 1, 'n_estimators': 10}
# 0.457 (+/-0.002) for {'max_depth': 1, 'n_estimators': 30}
# 0.457 (+/-0.002) for {'max_depth': 1, 'n_estimators': 50}
# 0.457 (+/-0.002) for {'max_depth': 1, 'n_estimators': 100}
# 0.543 (+/-0.022) for {'max_depth': 3, 'n_estimators': 10}
# 0.548 (+/-0.022) for {'max_depth': 3, 'n_estimators': 30}
# 0.540 (+/-0.020) for {'max_depth': 3, 'n_estimators': 50}
# 0.537 (+/-0.022) for {'max_depth': 3, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           3       0.00      0.00      0.00         9
#           4       0.78      0.12      0.20        60
#           5       0.69      0.63      0.66       458
#           6       0.60      0.79      0.68       630
#           7       0.66      0.48      0.56       267
#           8       0.76      0.35      0.48        46
#
# avg / total       0.65      0.64      0.62      1470
#
#
# RandomForestClassifier,wine,accuracy,None,50,0.66,0.64
# # Tuning hyper-parameters for accuracy, model MLPClassifier
#
# Best parameters set found on development set:
#
# {'activation': 'relu', 'alpha': 1e-06}
#
# Grid scores on development set:
#
# 0.537 (+/-0.033) for {'activation': 'identity', 'alpha': 0.001}
# 0.540 (+/-0.029) for {'activation': 'identity', 'alpha': 1e-05}
# 0.537 (+/-0.033) for {'activation': 'identity', 'alpha': 1e-06}
# 0.547 (+/-0.029) for {'activation': 'relu', 'alpha': 0.001}
# 0.548 (+/-0.027) for {'activation': 'relu', 'alpha': 1e-05}
# 0.552 (+/-0.029) for {'activation': 'relu', 'alpha': 1e-06}
# 0.532 (+/-0.031) for {'activation': 'logistic', 'alpha': 0.001}
# 0.531 (+/-0.036) for {'activation': 'logistic', 'alpha': 1e-05}
# 0.532 (+/-0.036) for {'activation': 'logistic', 'alpha': 1e-06}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           3       0.00      0.00      0.00         9
#           4       0.00      0.00      0.00        60
#           5       0.60      0.51      0.55       458
#           6       0.49      0.77      0.60       630
#           7       0.46      0.18      0.26       267
#           8       0.00      0.00      0.00        46
#
# avg / total       0.48      0.52      0.48      1470
#
#
# MLPClassifier,wine,accuracy,relu,1e-06,0.55,0.52
# # Tuning hyper-parameters for accuracy, model SVC
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.967 (+/-0.071) for {'C': 1, 'kernel': 'linear'}
# 0.934 (+/-0.072) for {'C': 1, 'kernel': 'poly'}
# 0.730 (+/-0.127) for {'C': 1, 'kernel': 'rbf'}
# 0.605 (+/-0.013) for {'C': 1, 'kernel': 'sigmoid'}
# 0.961 (+/-0.095) for {'C': 10, 'kernel': 'linear'}
# 0.934 (+/-0.072) for {'C': 10, 'kernel': 'poly'}
# 0.750 (+/-0.102) for {'C': 10, 'kernel': 'rbf'}
# 0.605 (+/-0.013) for {'C': 10, 'kernel': 'sigmoid'}
# 0.961 (+/-0.095) for {'C': 100, 'kernel': 'linear'}
# 0.934 (+/-0.072) for {'C': 100, 'kernel': 'poly'}
# 0.750 (+/-0.102) for {'C': 100, 'kernel': 'rbf'}
# 0.592 (+/-0.042) for {'C': 100, 'kernel': 'sigmoid'}
# 0.961 (+/-0.095) for {'C': 1000, 'kernel': 'linear'}
# 0.934 (+/-0.072) for {'C': 1000, 'kernel': 'poly'}
# 0.750 (+/-0.102) for {'C': 1000, 'kernel': 'rbf'}
# 0.599 (+/-0.060) for {'C': 1000, 'kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.96      0.96      0.96        45
#           1       0.90      0.90      0.90        21
#
# avg / total       0.94      0.94      0.94        66
#
#
# SVC,congress,accuracy,1,linear,0.97,0.94
# # Tuning hyper-parameters for accuracy, model KNeighborsClassifier
#
# Best parameters set found on development set:
#
# {'n_neighbors': 1, 'weights': 'uniform'}
#
# Grid scores on development set:
#
# 0.757 (+/-0.129) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.757 (+/-0.129) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.658 (+/-0.086) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.671 (+/-0.069) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.612 (+/-0.095) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.664 (+/-0.124) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.566 (+/-0.054) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.632 (+/-0.076) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.625 (+/-0.032) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.671 (+/-0.036) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.586 (+/-0.092) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.684 (+/-0.049) for {'n_neighbors': 30, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.87      0.87      0.87        45
#           1       0.71      0.71      0.71        21
#
# avg / total       0.82      0.82      0.82        66
#
#
# KNeighborsClassifier,congress,accuracy,1,uniform,0.76,0.82
# # Tuning hyper-parameters for accuracy, model RandomForestClassifier
#
# Best parameters set found on development set:
#
# {'max_depth': None, 'n_estimators': 30}
#
# Grid scores on development set:
#
# 0.954 (+/-0.032) for {'max_depth': None, 'n_estimators': 10}
# 0.974 (+/-0.076) for {'max_depth': None, 'n_estimators': 30}
# 0.974 (+/-0.076) for {'max_depth': None, 'n_estimators': 50}
# 0.967 (+/-0.071) for {'max_depth': None, 'n_estimators': 100}
# 0.941 (+/-0.076) for {'max_depth': 1, 'n_estimators': 10}
# 0.934 (+/-0.072) for {'max_depth': 1, 'n_estimators': 30}
# 0.947 (+/-0.052) for {'max_depth': 1, 'n_estimators': 50}
# 0.928 (+/-0.049) for {'max_depth': 1, 'n_estimators': 100}
# 0.947 (+/-0.079) for {'max_depth': 3, 'n_estimators': 10}
# 0.967 (+/-0.071) for {'max_depth': 3, 'n_estimators': 30}
# 0.967 (+/-0.071) for {'max_depth': 3, 'n_estimators': 50}
# 0.967 (+/-0.071) for {'max_depth': 3, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      0.93      0.97        45
#           1       0.88      1.00      0.93        21
#
# avg / total       0.96      0.95      0.96        66
#
#
# RandomForestClassifier,congress,accuracy,None,30,0.97,0.95
# # Tuning hyper-parameters for accuracy, model MLPClassifier
# Best parameters set found on development set:
#
# {'activation': 'logistic', 'alpha': 1e-05}
#
# Grid scores on development set:
#
# 0.612 (+/-0.273) for {'activation': 'identity', 'alpha': 0.001}
# 0.691 (+/-0.219) for {'activation': 'identity', 'alpha': 1e-05}
# 0.520 (+/-0.207) for {'activation': 'identity', 'alpha': 1e-06}
# 0.618 (+/-0.413) for {'activation': 'relu', 'alpha': 0.001}
# 0.480 (+/-0.195) for {'activation': 'relu', 'alpha': 1e-05}
# 0.480 (+/-0.207) for {'activation': 'relu', 'alpha': 1e-06}
# 0.862 (+/-0.268) for {'activation': 'logistic', 'alpha': 0.001}
# 0.947 (+/-0.068) for {'activation': 'logistic', 'alpha': 1e-05}
# 0.895 (+/-0.294) for {'activation': 'logistic', 'alpha': 1e-06}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.98      0.93      0.95        45
#           1       0.87      0.95      0.91        21
#
# avg / total       0.94      0.94      0.94        66
#
#
# MLPClassifier,congress,accuracy,logistic,1e-05,0.95,0.94

# %%
import pandas as pd
import numpy as np
from IPython.display import display, Markdown, Latex, HTML

# %% [markdown]
# Parameter combinations by GridSearchCV for all classifiers. Sorted in order of accuracy.
# "model,dataset,scoring,P1_best,P2_best,cv_acc,val_acc"

# %%
df_def = pd.read_csv('results/params_tuning.csv')
res = df_def.drop(['scoring', 'cv_acc', 'val_acc'], axis=1).groupby(['model','P1_best', 'P2_best']).count()
display(HTML(res.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>dataset</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th>P1_best</th>
#       <th>P2_best</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="6" valign="top">KNeighborsClassifier</th>
#       <th>1</th>
#       <th>uniform</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">10</th>
#       <th>distance</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>uniform</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">3</th>
#       <th>distance</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>uniform</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <th>distance</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th rowspan="6" valign="top">MLPClassifier</th>
#       <th>identity</th>
#       <th>0.001</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">logistic</th>
#       <th>0.001</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1e-05</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1e-06</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">relu</th>
#       <th>0.001</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1e-06</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">RandomForestClassifier</th>
#       <th rowspan="2" valign="top">3</th>
#       <th>10</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">None</th>
#       <th>10</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th rowspan="6" valign="top">SVC</th>
#       <th>1</th>
#       <th>linear</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <th>rbf</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">100</th>
#       <th>linear</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>rbf</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">1000</th>
#       <th>poly</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>rbf</th>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
